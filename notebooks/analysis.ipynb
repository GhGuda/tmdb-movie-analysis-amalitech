# %%
import sys
import numpy as np
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %% [markdown]
# ## TMDB Movie Analysis
#
# This notebook presents KPI analysis and visual insights
# derived from TMDB movie data.

# %%
from scripts.pipeline import run_pipeline
from scripts.analysis.kpi import (
    get_all_kpis,
    best_rated_sci_fi_movies,
    uma_thurman_tarantino_movies,
    compare_franchise_vs_standalone_performance,
    most_successful_franchises,
    most_successful_directors
)

# %% [markdown]
# ## Run pipeline

# %%
movies_df = run_pipeline()
# Out:
# Starting TMDB movie data pipeline...
# 2026-01-23 16:18:13,026 - WARNING - Attempt 1 failed for movie 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?api_key=c7de17767d181fa17ba12c5bda9cc3b3&append_to_response=credits
# 2026-01-23 16:18:16,508 - WARNING - Attempt 2 failed for movie 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?api_key=c7de17767d181fa17ba12c5bda9cc3b3&append_to_response=credits
# 2026-01-23 16:18:19,688 - WARNING - Attempt 3 failed for movie 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?api_key=c7de17767d181fa17ba12c5bda9cc3b3&append_to_response=credits
# 2026-01-23 16:18:21,690 - ERROR - All 3 attempts failed for movie 0.
# 2026-01-23 16:18:23,062 - INFO - Fetched movie ID 299534
# 2026-01-23 16:18:24,515 - INFO - Fetched movie ID 19995
# 2026-01-23 16:18:25,731 - INFO - Fetched movie ID 140607
# 2026-01-23 16:18:27,088 - INFO - Fetched movie ID 299536
# 2026-01-23 16:18:28,496 - INFO - Fetched movie ID 597
# 2026-01-23 16:18:29,794 - INFO - Fetched movie ID 135397
# 2026-01-23 16:18:30,950 - INFO - Fetched movie ID 420818
# 2026-01-23 16:18:32,154 - INFO - Fetched movie ID 24428
# 2026-01-23 16:18:33,243 - INFO - Fetched movie ID 168259
# 2026-01-23 16:18:34,331 - INFO - Fetched movie ID 99861
# 2026-01-23 16:18:35,392 - INFO - Fetched movie ID 284054
# 2026-01-23 16:18:36,374 - INFO - Fetched movie ID 12445
# 2026-01-23 16:18:37,381 - INFO - Fetched movie ID 181808
# 2026-01-23 16:18:38,523 - INFO - Fetched movie ID 330457
# 2026-01-23 16:18:39,784 - INFO - Fetched movie ID 351286
# 2026-01-23 16:18:40,880 - INFO - Fetched movie ID 109445
# 2026-01-23 16:18:42,175 - INFO - Fetched movie ID 321612
# 2026-01-23 16:18:43,160 - INFO - Fetched movie ID 260513
# Extraction complete. 18 movies collected.
# Pipeline completed successfully.

# %% [markdown]
# ## KPI Section

# %% [markdown]
# Get KPIs

# %%
kpis = get_all_kpis(movies_df)

# %% [markdown]
# ## Highest Revenue

# %%
kpis['highest_revenue'][['title', 'revenue_musd']]
# Out:
#                            title  revenue_musd
# 6                         Avatar   2923.706026
# 10             Avengers: Endgame   2799.439100
# 16                       Titanic   2264.162353
# 3   Star Wars: The Force Awakens   2068.223624
# 11        Avengers: Infinity War   2052.415039
# 2                 Jurassic World   1671.537444
# 15                 The Lion King   1662.020819
# 7                   The Avengers   1518.815515
# 4                      Furious 7   1515.400000
# 13                     Frozen II   1453.683476

# %% [markdown]
# ## Highest Budget

# %%
kpis['highest_budget'][['title', 'budget_musd']]
# Out:
#                            title  budget_musd
# 10             Avengers: Endgame        356.0
# 5       Star Wars: The Last Jedi        300.0
# 11        Avengers: Infinity War        300.0
# 15                 The Lion King        260.0
# 3   Star Wars: The Force Awakens        245.0
# 6                         Avatar        237.0
# 17       Avengers: Age of Ultron        235.0
# 7                   The Avengers        220.0
# 16                       Titanic        200.0
# 8                  Incredibles 2        200.0

# %% [markdown]
# ## Highest Profit

# %%
kpis['highest_profit'][['title', 'profit']]
# Out:
#                            title       profit
# 6                         Avatar  2686.706026
# 10             Avengers: Endgame  2443.439100
# 16                       Titanic  2064.162353
# 3   Star Wars: The Force Awakens  1823.223624
# 11        Avengers: Infinity War  1752.415039
# 2                 Jurassic World  1521.537444
# 15                 The Lion King  1402.020819
# 4                      Furious 7  1325.400000
# 13                     Frozen II  1303.683476
# 7                   The Avengers  1298.815515

# %% [markdown]
# ## Lowest Profit

# %%
kpis['lowest_profit'][['title', 'profit']]
# Out:
#                                            title       profit
# 5                       Star Wars: The Last Jedi  1032.698830
# 8                                  Incredibles 2  1043.225667
# 12                          Beauty and the Beast  1106.115964
# 0                                         Frozen  1124.219009
# 14                Jurassic World: Fallen Kingdom  1140.469037
# 9                                  Black Panther  1149.926083
# 17                       Avengers: Age of Ultron  1170.403694
# 1   Harry Potter and the Deathly Hallows: Part 2  1216.511219
# 7                                   The Avengers  1298.815515
# 13                                     Frozen II  1303.683476

# %% [markdown]
# ## Highest ROI

# %%
kpis['highest_roi'][['title', 'roi']]
# Out:
#                                            title        roi
# 6                                         Avatar  11.336312
# 16                                       Titanic  10.320812
# 2                                 Jurassic World  10.143583
# 1   Harry Potter and the Deathly Hallows: Part 2   9.732090
# 13                                     Frozen II   8.691223
# 0                                         Frozen   7.494793
# 3                   Star Wars: The Force Awakens   7.441729
# 4                                      Furious 7   6.975789
# 12                          Beauty and the Beast   6.913225
# 10                             Avengers: Endgame   6.863593

# %% [markdown]
# ## Lowest ROI

# %%
kpis['lowest_roi'][['title', 'roi']]
# Out:
#                              title       roi
# 5         Star Wars: The Last Jedi  3.442329
# 17         Avengers: Age of Ultron  4.980441
# 8                    Incredibles 2  5.216128
# 15                   The Lion King  5.392388
# 9                    Black Panther  5.749630
# 11          Avengers: Infinity War  5.841383
# 7                     The Avengers  5.903707
# 14  Jurassic World: Fallen Kingdom  6.708641
# 10               Avengers: Endgame  6.863593
# 12            Beauty and the Beast  6.913225

# %% [markdown]
# ## Most Voted Movies

# %%
kpis['most_voted'][['title', 'vote_count']]
# Out:
#                                            title  vote_count
# 7                                   The Avengers       35009
# 6                                         Avatar       33224
# 11                        Avengers: Infinity War       31330
# 10                             Avengers: Endgame       27116
# 16                                       Titanic       26648
# 17                       Avengers: Age of Ultron       23996
# 9                                  Black Panther       23069
# 1   Harry Potter and the Deathly Hallows: Part 2       21565
# 2                                 Jurassic World       21211
# 3                   Star Wars: The Force Awakens       20190

# %% [markdown]
# ## Highest Rated Movies

# %%
kpis['highest_rated'][['title', 'vote_average']]
# Out:
#                                            title  vote_average
# 10                             Avengers: Endgame         8.238
# 11                        Avengers: Infinity War         8.235
# 1   Harry Potter and the Deathly Hallows: Part 2         8.083
# 16                                       Titanic         7.902
# 7                                   The Avengers         7.901
# 6                                         Avatar         7.600
# 8                                  Incredibles 2         7.454
# 9                                  Black Panther         7.365
# 17                       Avengers: Age of Ultron         7.271
# 3                   Star Wars: The Force Awakens         7.254

# %% [markdown]
# ## Lowest Rated Movies

# %%
kpis['lowest_rated'][['title', 'vote_average']]
# Out:
#                              title  vote_average
# 14  Jurassic World: Fallen Kingdom         6.500
# 2                   Jurassic World         6.700
# 5         Star Wars: The Last Jedi         6.762
# 12            Beauty and the Beast         6.969
# 15                   The Lion King         7.099
# 4                        Furious 7         7.220
# 13                       Frozen II         7.238
# 0                           Frozen         7.248
# 3     Star Wars: The Force Awakens         7.254
# 17         Avengers: Age of Ultron         7.271

# %% [markdown]
# ## Most Popular Movies

# %%
kpis['most_popular'][['title', 'popularity']]
# Out:
#                                            title  popularity
# 6                                         Avatar     70.1711
# 7                                   The Avengers     65.5674
# 16                                       Titanic     35.3101
# 11                        Avengers: Infinity War     28.8523
# 10                             Avengers: Endgame     18.6659
# 0                                         Frozen     17.6355
# 1   Harry Potter and the Deathly Hallows: Part 2     17.6262
# 12                          Beauty and the Beast     17.2818
# 17                       Avengers: Age of Ultron     15.7724
# 15                                 The Lion King     12.3164

# %% [markdown]
# # Best-rated Science Fiction Action movies starring Bruce Willis

# %%
kpiBestRatedSciFi = best_rated_sci_fi_movies(movies_df)

kpiBestRatedSciFi[['title', 'genres', 'cast']]
# Out:
# Empty DataFrame
# Columns: [title, genres, cast]
# Index: []

# %% [markdown]
# # Movies starring Uma Thurman, directed by Quentin Tarantino

# %%
kpiUmaThurmanTarantinoMovies = uma_thurman_tarantino_movies(movies_df)

kpiUmaThurmanTarantinoMovies[['title', 'genres', 'cast']]
# Out:
# Empty DataFrame
# Columns: [title, genres, cast]
# Index: []

# %% [markdown]
# # Franchise vs Standalone Movie Performance

# %% [markdown]
# # Compare movie franchises (belongs_to_collection) vs. standalone movies in terms of

# %%
compare_franchise_vs_standalone_performance(movies_df)
# Out:
#                 mean_revenue  median_roi  mean_budget  mean_popularity  \
# franchise_type
# Standalone       1765.139159    8.617018        180.0        26.295950
# Franchise        1682.668411    6.786117        218.0        20.526512
#
#                 mean_rating
# franchise_type
# Standalone           7.4355
# Franchise            7.3855

# %% [markdown]
# # Find the Most Successful Movie Franchises based on:

# %%
most_successful_franchises(movies_df)
# Out:
#                                      total_movies  total_budget  mean_budget  \
# collection_name
# Avatar Collection                               1         237.0       237.00
# The Avengers Collection                         4        1111.0       277.75
# Star Wars Collection                            2         545.0       272.50
# The Lion King (Reboot) Collection               1         260.0       260.00
# The Fast and the Furious Collection             1         190.0       190.00
# Jurassic Park Collection                        2         320.0       160.00
# Frozen Collection                               2         300.0       150.00
# Black Panther Collection                        1         200.0       200.00
# Harry Potter Collection                         1         125.0       125.00
# The Incredibles Collection                      1         200.0       200.00
#
#                                      total_revenue  mean_revenue  mean_rating
# collection_name
# Avatar Collection                      2923.706026   2923.706026      7.60000
# The Avengers Collection                7776.073348   1944.018337      7.91125
# Star Wars Collection                   3400.922454   1700.461227      7.00800
# The Lion King (Reboot) Collection      1662.020819   1662.020819      7.09900
# The Fast and the Furious Collection    1515.400000   1515.400000      7.22000
# Jurassic Park Collection               2982.006481   1491.003241      6.60000
# Frozen Collection                      2727.902485   1363.951242      7.24300
# Black Panther Collection               1349.926083   1349.926083      7.36500
# Harry Potter Collection                1341.511219   1341.511219      8.08300
# The Incredibles Collection             1243.225667   1243.225667      7.45400

# %% [markdown]
# # Find the Most Successful Directors based on

# %%
most_successful_directors(movies_df)
# Out:
#                          total_movies  total_revenue  mean_rating
# director
# James Cameron                       2    5187.868379        7.751
# Joss Whedon                         2    2924.219209        7.586
# Anthony Russo|Joe Russo             1    2799.439100        8.238
# Jennifer Lee|Chris Buck             2    2727.902485        7.243
# J.J. Abrams                         1    2068.223624        7.254
# Joe Russo|Anthony Russo             1    2052.415039        8.235
# Colin Trevorrow                     1    1671.537444        6.700
# Jon Favreau                         1    1662.020819        7.099
# James Wan                           1    1515.400000        7.220
# Ryan Coogler                        1    1349.926083        7.365
# David Yates                         1    1341.511219        8.083
# Rian Johnson                        1    1332.698830        6.762
# J.A. Bayona                         1    1310.469037        6.500
# Bill Condon                         1    1266.115964        6.969
# Brad Bird                           1    1243.225667        7.454

# %% [markdown]
# ## Visual Analysis
#
# The following plots explore relationships and trends
# in movie performance metrics.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Revenue vs Budget
# This plot shows how movie budgets relate to revenue outcomes.

# %%
plt.figure(figsize=(10,6))
plt.scatter(movies_df['budget_musd'], movies_df['revenue_musd'], alpha=0.7)
plt.title('Revenue vs Budget')
plt.xlabel('Budget (USD)')
plt.ylabel('Revenue (USD)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### ROI Distribution by Genre
# This shows how return on investment varies across genres.

# %%
df_genres = movies_df.copy()
df_genres['roi'] = df_genres['revenue_musd'] / df_genres['budget_musd']
df_genres = df_genres[df_genres["budget_musd"] >= 10]
df_genres['genres'] = df_genres['genres'].str.split('|')
df_genres = df_genres.explode('genres')

plt.figure(figsize=(12,6))
df_genres.boxplot(column='roi', by='genres', rot=90)
plt.title("ROI Distribution by Genre")
plt.suptitle("")
plt.xlabel("Genre")
plt.ylabel("ROI")
plt.show()

# %% [markdown]
# ### Popularity vs Rating
# Examines whether more popular movies are better rated.

# %%
plt.figure(figsize=(10,6))
plt.scatter(movies_df['popularity'], movies_df['vote_average'])
plt.xlabel("Popularity")
plt.ylabel("Rating")
plt.title("Popularity vs Rating")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Yearly Box Office Trends
# Shows total revenue trends over time.

# %%
movies_df['year'] = movies_df['release_date'].dt.year
yearly = movies_df.groupby('year')['revenue_musd'].sum().reset_index()

plt.figure(figsize=(12,6))
plt.plot(yearly['year'], yearly['revenue_musd'])
plt.xlabel("Year")
plt.ylabel("Total Revenue")
plt.title("Yearly Box Office Revenue Trends")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Franchise vs Standalone Performance
# Comparison of ROI between franchise and standalone movies.

# %%
df_franchise = movies_df.copy()

df_franchise["roi"] = (
    (df_franchise["revenue_musd"] - df_franchise["budget_musd"]) /
    df_franchise["budget_musd"]
).replace([np.inf, -np.inf], np.nan)


df_franchise = df_franchise[df_franchise["budget_musd"] >= 10]

df_franchise["franchise_type"] = df_franchise["belongs_to_collection"].notna().map({
    True: "Franchise",
    False: "Standalone"
})

franchise_stats = df_franchise.groupby('franchise_type')[['roi']].mean()

plt.figure(figsize=(8,5))
franchise_stats['roi'].plot(kind='bar')
plt.title("ROI: Franchise vs Standalone")
plt.ylabel("ROI")
plt.grid(True)
plt.show()
