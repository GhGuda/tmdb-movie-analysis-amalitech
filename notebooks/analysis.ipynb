# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %% [markdown]
# ## TMDB Movie Analysis
#
# Objective:
# Analyze movie performance using KPIs such as revenue, profit, ROI,
# ratings, franchises, and directors.

# %%
import pandas as pd
from scripts.pipeline import run_pipeline
from scripts.analysis.kpi import (
    rank_movies,
    search_movies,
    best_rated_sci_fi_movies,
    uma_thurman_tarantino_movies,
    franchise_vs_standalone_performance,
    most_successful_franchises,
    most_successful_directors
)

# %%
movies_df = run_pipeline()
movies_df.head()
# Out:
# Starting TMDB movie data pipeline...
# 2026-01-13 15:51:53,072 - WARNING - Attempt 1 failed for movie 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?api_key=c7de17767d181fa17ba12c5bda9cc3b3&append_to_response=credits
# 2026-01-13 15:51:55,696 - WARNING - Attempt 2 failed for movie 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?api_key=c7de17767d181fa17ba12c5bda9cc3b3&append_to_response=credits
# 2026-01-13 15:51:58,325 - WARNING - Attempt 3 failed for movie 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?api_key=c7de17767d181fa17ba12c5bda9cc3b3&append_to_response=credits
# 2026-01-13 15:52:00,327 - ERROR - All 3 attempts failed for movie 0.
# 2026-01-13 15:52:01,029 - INFO - Fetched movie ID 299534
# 2026-01-13 15:52:01,828 - INFO - Fetched movie ID 19995
# 2026-01-13 15:52:02,531 - INFO - Fetched movie ID 140607
# 2026-01-13 15:52:03,347 - INFO - Fetched movie ID 299536
# 2026-01-13 15:52:04,057 - INFO - Fetched movie ID 597
# 2026-01-13 15:52:04,721 - INFO - Fetched movie ID 135397
# 2026-01-13 15:52:05,343 - INFO - Fetched movie ID 420818
# 2026-01-13 15:52:06,009 - INFO - Fetched movie ID 24428
# 2026-01-13 15:52:06,647 - INFO - Fetched movie ID 168259
# 2026-01-13 15:52:07,297 - INFO - Fetched movie ID 99861
# 2026-01-13 15:52:07,974 - INFO - Fetched movie ID 284054
# 2026-01-13 15:52:08,614 - INFO - Fetched movie ID 12445
# 2026-01-13 15:52:09,286 - INFO - Fetched movie ID 181808
# 2026-01-13 15:52:09,964 - INFO - Fetched movie ID 330457
# 2026-01-13 15:52:10,635 - INFO - Fetched movie ID 351286
# 2026-01-13 15:52:11,293 - INFO - Fetched movie ID 109445
# 2026-01-13 15:52:11,947 - INFO - Fetched movie ID 321612
# 2026-01-13 15:52:12,610 - INFO - Fetched movie ID 260513
# Extraction complete. 18 movies collected.
# Pipeline completed successfully.
#        id                                         title  \
# 0  109445                                        Frozen
# 1   12445  Harry Potter and the Deathly Hallows: Part 2
# 2  135397                                Jurassic World
# 3  140607                  Star Wars: The Force Awakens
# 4  168259                                     Furious 7
#
#                                              tagline release_date  \
# 0  Only the act of true love will thaw a frozen h...   2013-11-20
# 1                                       It all ends.   2011-07-12
# 2                                  The park is open.   2015-06-06
# 3                      Every generation has a story.   2015-12-15
# 4                               Vengeance hits home.   2015-04-01
#
#                                       genres  \
# 0         Animation|Family|Adventure|Fantasy
# 1                          Adventure|Fantasy
# 2  Action|Adventure|Science Fiction|Thriller
# 3           Adventure|Action|Science Fiction
# 4                      Action|Crime|Thriller
#
#                  belongs_to_collection original_language  budget_musd  \
# 0                    Frozen Collection                en        150.0
# 1              Harry Potter Collection                en        125.0
# 2             Jurassic Park Collection                en        150.0
# 3                 Star Wars Collection                en        245.0
# 4  The Fast and the Furious Collection                en        190.0
#
#    revenue_musd                               production_companies  ...  \
# 0   1274.219009                      Walt Disney Animation Studios  ...
# 1   1341.511219                 Warner Bros. Pictures|Heyday Films  ...
# 2   1671.537444  Amblin Entertainment|Universal Pictures|Legend...  ...
# 3   2068.223624                           Lucasfilm Ltd.|Bad Robot  ...
# 4   1515.400000          Original Film|One Race|Universal Pictures  ...
#
#   vote_average  popularity  runtime  \
# 0        7.248     17.6355      102
# 1        8.083     17.6262      130
# 2        6.700     11.0354      124
# 3        7.254      9.7883      136
# 4        7.220     10.7110      139
#
#                                             overview  \
# 0  Young princess Anna of Arendelle dreams about ...
# 1  Harry, Ron and Hermione continue their quest t...
# 2  Twenty-two years after the events of Jurassic ...
# 3  Thirty years after defeating the Galactic Empi...
# 4  Deckard Shaw seeks revenge against Dominic Tor...
#
#                   spoken_languages                       poster_path  \
# 0                          English  /itAKcobTYGpYT8Phwjd8c9hleTo.jpg
# 1                          English  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg
# 2                          English  /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg
# 3                          English  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 4  العربية|English|Español|ภาษาไทย  /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg
#
#                                                 cast cast_size  \
# 0  Idina Menzel|Kristen Bell|Jonathan Groff|Josh ...        60
# 1  Daniel Radcliffe|Emma Watson|Rupert Grint|Ralp...       105
# 2  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...        53
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       183
# 4  Vin Diesel|Paul Walker|Dwayne Johnson|Michelle...        49
#
#                   director  crew_size
# 0  Jennifer Lee|Chris Buck        285
# 1              David Yates        159
# 2          Colin Trevorrow        428
# 3              J.J. Abrams        264
# 4                James Wan        228
#
# [5 rows x 22 columns]
